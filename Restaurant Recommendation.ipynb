# %%
import pandas as pd

# %%
data = pd.read_csv('Dataset .csv')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.dropna(subset=['Cuisines'], inplace=True)

# %%
print(data.isnull().sum())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.shape
# Out:
# (9542, 21)

# %%
for col in data.columns:
    print(f"Unique values for column '{col}':", len(data[col].unique()))
# Out:
# Unique values for column 'Restaurant ID': 9542
# Unique values for column 'Restaurant Name': 7437
# Unique values for column 'Country Code': 15
# Unique values for column 'City': 140
# Unique values for column 'Address': 8910
# Unique values for column 'Locality': 1206
# Unique values for column 'Locality Verbose': 1263
# Unique values for column 'Longitude': 8111
# Unique values for column 'Latitude': 8668
# Unique values for column 'Cuisines': 1825
# Unique values for column 'Average Cost for two': 140
# Unique values for column 'Currency': 12
# Unique values for column 'Has Table booking': 2
# Unique values for column 'Has Online delivery': 2
# Unique values for column 'Is delivering now': 2
# Unique values for column 'Switch to order menu': 1
# Unique values for column 'Price range': 4
# Unique values for column 'Aggregate rating': 33
# Unique values for column 'Rating color': 6
# Unique values for column 'Rating text': 6
# Unique values for column 'Votes': 1012

# %%
selected_columns = ['Restaurant ID','Restaurant Name','City','Address','Cuisines','Price range','Aggregate rating','Has Online delivery']
data = data[selected_columns]
data
# Out:
#       Restaurant ID           Restaurant Name              City  \
# 0           6317637          Le Petit Souffle       Makati City
# 1           6304287          Izakaya Kikufuji       Makati City
# 2           6300002    Heat - Edsa Shangri-La  Mandaluyong City
# 3           6318506                      Ooma  Mandaluyong City
# 4           6314302               Sambo Kojin  Mandaluyong City
# ...             ...                       ...               ...
# 9546        5915730               Naml۱ Gurme         ��stanbul
# 9547        5908749              Ceviz A��ac۱         ��stanbul
# 9548        5915807                     Huqqa         ��stanbul
# 9549        5916112               A���k Kahve         ��stanbul
# 9550        5927402  Walter's Coffee Roastery         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# ...

# %%
data.shape
# Out:
# (9542, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Restaurant ID        9542 non-null   int64
#  1   Restaurant Name      9542 non-null   object
#  2   City                 9542 non-null   object
#  3   Address              9542 non-null   object
#  4   Cuisines             9542 non-null   object
#  5   Price range          9542 non-null   int64
#  6   Aggregate rating     9542 non-null   float64
#  7   Has Online delivery  9542 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 670.9+ KB

# %%
def restaurant_details_by_name(restaurant_name, data):
    restaurants= data[data['Restaurant Name'] == restaurant_name]
    if restaurants.empty:
        return "No Data Available."
    else:
        for index, row in restaurants.iterrows():
            print("Restaurant ID:", row['Restaurant ID'])
            print("Restaurant Name:", row['Restaurant Name'])
            print("City:", row['City'])
            print("Address:", row['Address'])
            print("Cuisines:", row['Cuisines'])
            print("Price range:", row['Price range'])
            print("Aggregate rating:", row['Aggregate rating'])
            print("Has Online delivery:", row['Has Online delivery'])
            print("\n")
    

userdata=input("Enter Restaurent Name: ")
restaurant_details_by_name(userdata, data)
# Out:
# Enter Restaurent Name: A���k Kahve
# Restaurant ID: 5916112
# Restaurant Name: A���k Kahve
# City: ��stanbul
# Address: Kuru�_e��me Mahallesi, Muallim Naci Caddesi, No 64/B, Be��ikta��, ��stanbul
# Cuisines: Restaurant Cafe
# Price range: 4
# Aggregate rating: 4.0
# Has Online delivery: No

# %%
def restaurant_details_by_city(city, data):
    restaurants= data[data['City'] == city]
    if restaurants.empty:
        return "No data available."
    else:
        for index, row in restaurants.iterrows():
            print("Restaurant ID:", row['Restaurant ID'])
            print("Restaurant Name:", row['Restaurant Name'])
            print("City:", row['City'])
            print("Address:", row['Address'])
            print("Cuisines:", row['Cuisines'])
            print("Price range:", row['Price range'])
            print("Aggregate rating:", row['Aggregate rating'])
            print("Has Online delivery:", row['Has Online delivery'])
            print("\n")
    

user_data=input("Enter City: ")
restaurant_details_by_city(user_data, data)
# Out:
# Enter City: gyt
# 'No data available.'

# %%
def restaurant_details_by_price(price, data):
    restaurants = data[data['Price range'] == price]
    if restaurants.empty:
        return "No data available."
    else:
        num_restaurants = min(10, len(restaurants))
        print(f"Total number of restaurants with price range {price}: {len(restaurants)}")
        print(f"Displaying a sample of {num_restaurants} restaurants:\n")
        for index, row in restaurants.head(10).iterrows():
            print("Restaurant ID:", row['Restaurant ID'])
            print("Restaurant Name:", row['Restaurant Name'])
            print("City:", row['City'])
            print("Address:", row['Address'])
            print("Cuisines:", row['Cuisines'])
            print("Price range:", row['Price range'])
            print("Aggregate rating:", row['Aggregate rating'])
            print("Has Online delivery:", row['Has Online delivery'])
            print("\n")
    

user_data=int(input("Enter price(1-4): "))
restaurant_details_by_price(user_data, data)
# Out:
# Enter price(1-4): 4
# Total number of restaurants with price range 4: 586
# Displaying a sample of 10 restaurants:
#
# Restaurant ID: 6300002
# Restaurant Name: Heat - Edsa Shangri-La
# City: Mandaluyong City
# Address: Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City
# Cuisines: Seafood, Asian, Filipino, Indian
# Price range: 4
# Aggregate rating: 4.4
#
#
# Restaurant ID: 6318506
# Restaurant Name: Ooma
# City: Mandaluyong City
# Address: Third Floor, Mega Fashion Hall, SM Megamall, Ortigas, Mandaluyong City
# Cuisines: Japanese, Sushi
# Price range: 4
# Aggregate rating: 4.9
#
#
# Restaurant ID: 6314302
# Restaurant Name: Sambo Kojin
# City: Mandaluyong City
# Address: Third Floor, Mega Atrium, SM Megamall, Ortigas, Mandaluyong City
# Cuisines: Japanese, Korean
# Price range: 4
# Aggregate rating: 4.8
#
#
# Restaurant ID: 6300781
# Restaurant Name: Buffet 101
# City: Pasay City
# Address: Building K, SM By The Bay, Sunset Boulevard, Mall of Asia Complex (MOA), Pasay City
# ...

# %%
def restaurant_details_by_rating(rating, data):
    restaurants = data[data['Aggregate rating'] >= aggregate_rating]
    if restaurants.empty:
        return "No data available."
    else:
        num_restaurants = min(10, len(restaurants))
        print(f"Total number of restaurants with minimum aggregate rating {rating}: {len(restaurants)}")
        print(f"Displaying a sample of {num_restaurants} restaurants:\n")
        for index, row in restaurants.head(10).iterrows():
            print("Restaurant ID:", row['Restaurant ID'])
            print("Restaurant Name:", row['Restaurant Name'])
            print("City:", row['City'])
            print("Address:", row['Address'])
            print("Cuisines:", row['Cuisines'])
            print("Price range:", row['Price range'])
            print("Aggregate rating:", row['Aggregate rating'])
            print("Has Online delivery:", row['Has Online delivery'])
            print("\n")
    

user_data=float(input("Enter minimum aggregate rating(0-4.9): "))
restaurant_details_by_rating(user_data, data)
# Out:
# Enter minimum aggregate rating(0-4.9): 3.8
# Total number of restaurants with minimum aggregate rating 3.8: 1378
# Displaying a sample of 10 restaurants:
#
# Restaurant ID: 6317637
# Restaurant Name: Le Petit Souffle
# City: Makati City
# Address: Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City
# Cuisines: French, Japanese, Desserts
# Price range: 3
# Aggregate rating: 4.8
#
#
# Restaurant ID: 6304287
# Restaurant Name: Izakaya Kikufuji
# City: Makati City
# Address: Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City
# Cuisines: Japanese
# Price range: 3
# Aggregate rating: 4.5
#
#
# Restaurant ID: 6300002
# Restaurant Name: Heat - Edsa Shangri-La
# City: Mandaluyong City
# Address: Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City
# Cuisines: Seafood, Asian, Filipino, Indian
# Price range: 4
# Aggregate rating: 4.4
#
#
# Restaurant ID: 6318506
# Restaurant Name: Ooma
# City: Mandaluyong City
# ...

# %%
df=data
df['sep_cuisines'] = df['Cuisines'].str.split(', ')
df= df.explode('sep_cuisines').reset_index(drop=True)
df
# Out:
#        Restaurant ID           Restaurant Name              City  \
# 0            6317637          Le Petit Souffle       Makati City
# 1            6317637          Le Petit Souffle       Makati City
# 2            6317637          Le Petit Souffle       Makati City
# 3            6304287          Izakaya Kikufuji       Makati City
# 4            6300002    Heat - Edsa Shangri-La  Mandaluyong City
# ...              ...                       ...               ...
# 19705        5908749              Ceviz A��ac۱         ��stanbul
# 19706        5915807                     Huqqa         ��stanbul
# 19707        5915807                     Huqqa         ��stanbul
# 19708        5916112               A���k Kahve         ��stanbul
# 19709        5927402  Walter's Coffee Roastery         ��stanbul
#
#                                                  Address  \
# 0      Third Floor, Century City Mall, Kalayaan Avenu...
# 1      Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
def restaurant_details_by_cuisines(cuisines, data):
    restaurants = data[data['sep_cuisines'] == cuisines]
    if restaurants.empty:
        return "No data available."
    else:
        num_restaurants = min(10, len(restaurants))
        print(f"Total number of restaurants with cuisine {cuisines}: {len(restaurants)}")
        print(f"Displaying a sample of {num_restaurants} restaurants:\n")
        ids=set()
        for index, row in restaurants.head(10).iterrows():
            if(row['Restaurant ID'] not in ids):
                print("Restaurant ID:", row['Restaurant ID'])
                print("Restaurant Name:", row['Restaurant Name'])
                print("City:", row['City'])
                print("Address:", row['Address'])
                print("Cuisines:", row['Cuisines'])
                print("Price range:", row['Price range'])
                print("Aggregate rating:", row['Aggregate rating'])
                print("Has Online delivery:", row['Has Online delivery'])
                print("\n")
                ids.add(row['Restaurant ID'])
    

user_data=input("Enter cuisines you prefer: ")
restaurant_details_by_cuisines(user_data, df)
# Out:
# Enter cuisines you prefer: Seafood
# Total number of restaurants with cuisine Seafood: 174
# Displaying a sample of 10 restaurants:
#
# Restaurant ID: 6300002
# Restaurant Name: Heat - Edsa Shangri-La
# City: Mandaluyong City
# Address: Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City
# Cuisines: Seafood, Asian, Filipino, Indian
# Price range: 4
# Aggregate rating: 4.4
#
#
# Restaurant ID: 6301290
# Restaurant Name: Vikings
# City: Pasay City
# Address: Building B, By The Bay, Seaside Boulevard, Mall of Asia Complex (MOA), Pasay City
# Cuisines: Seafood, Filipino, Asian, European
# Price range: 4
# Aggregate rating: 4.2
#
#
# Restaurant ID: 6315438
# Restaurant Name: NIU by Vikings
# City: Taguig City
# Address: Sixth Floor, SM Aura Premier, C5 Road Corner 26th Street, Bonifacio Global City, Taguig City
# Cuisines: Seafood, American, Mediterranean, Japanese
# Price range: 4
# Aggregate rating: 4.7
#
#
# Restaurant ID: 6310406
# Restaurant Name: The Food Hall by Todd English
# ...

# %%
def restaurant_details_by_online_delivery(online_delivery, data):
    delivery_status = "Yes" if online_delivery == 1 else "No"
    restaurants = data[data['Has Online delivery'] == delivery_status]
    if restaurants.empty:
        print(f"No restaurants offer online delivery: {delivery_status}")
    else:
        num_restaurants = min(10, len(restaurants))
        print(f"Total number of restaurants offering online delivery: {len(restaurants)}")
        print(f"Displaying a sample of {num_restaurants} restaurants that offer online delivery:\n")
        for index, row in restaurants.head(10).iterrows():
            print("Restaurant ID:", row['Restaurant ID'])
            print("Restaurant Name:", row['Restaurant Name'])
            print("City:", row['City'])
            print("Address:", row['Address'])
            print("Cuisines:", row['Cuisines'])
            print("Price range:", row['Price range'])
            print("Aggregate rating:", row['Aggregate rating'])
            print("Has Online delivery:", row['Has Online delivery'])
            print("\n")

user_data = int(input("Enter 1 for restaurants with online delivery, 0 otherwise: "))
restaurant_details_by_online_delivery(user_data, data)
# Out:
# Enter 1 for restaurants with online delivery, 0 otherwise: 0
# Total number of restaurants offering online delivery: 7091
# Displaying a sample of 10 restaurants that offer online delivery:
#
# Restaurant ID: 6317637
# Restaurant Name: Le Petit Souffle
# City: Makati City
# Address: Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City
# Cuisines: French, Japanese, Desserts
# Price range: 3
# Aggregate rating: 4.8
# Has Online delivery: No
#
#
# Restaurant ID: 6304287
# Restaurant Name: Izakaya Kikufuji
# City: Makati City
# Address: Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City
# Cuisines: Japanese
# Price range: 3
# Aggregate rating: 4.5
# Has Online delivery: No
#
#
# Restaurant ID: 6300002
# Restaurant Name: Heat - Edsa Shangri-La
# City: Mandaluyong City
# Address: Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City
# Cuisines: Seafood, Asian, Filipino, Indian
# Price range: 4
# Aggregate rating: 4.4
# Has Online delivery: No
#
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19710 entries, 0 to 19709
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Restaurant ID        19710 non-null  int64
#  1   Restaurant Name      19710 non-null  object
#  2   City                 19710 non-null  object
#  3   Address              19710 non-null  object
#  4   Cuisines             19710 non-null  object
#  5   Price range          19710 non-null  int64
#  6   Aggregate rating     19710 non-null  float64
#  7   Has Online delivery  19710 non-null  object
#  8   sep_cuisines         19710 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.4+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Restaurant ID        9542 non-null   int64
#  1   Restaurant Name      9542 non-null   object
#  2   City                 9542 non-null   object
#  3   Address              9542 non-null   object
#  4   Cuisines             9542 non-null   object
#  5   Price range          9542 non-null   int64
#  6   Aggregate rating     9542 non-null   float64
#  7   Has Online delivery  9542 non-null   object
#  8   sep_cuisines         9542 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 745.5+ KB

# %%
def call_function(day):
    match day:
        case 1:
            userdata=input("Enter Restaurent Name: ")
            restaurant_details_by_name(userdata, data)
        case 2:
            user_data=input("Enter City: ")
            restaurant_details_by_city(user_data, data)
        case 3:
            user_data=int(input("Enter price(1-4): "))
            restaurant_details_by_price(user_data, data)
        case 4:
            user_data=float(input("Enter minimum aggregate rating(0-4.9): "))
            restaurant_details_by_rating(user_data, data)
        case 5:
            user_data=input("Enter cuisines you prefer: ")
            restaurant_details_by_cuisines(user_data, df)
        case 6:
            user_data = int(input("Enter 1 for restaurants with online delivery, 0 otherwise: "))
            restaurant_details_by_online_delivery(user_data, data)
        case _:
            return "Invalid data"

print("Select the criteria for restaurant recommendations:")
print("option 1: By Name\noption 2: By City\noption 3: By Price\noption 4: By Rating\noption 5: By Cuisines\noption 6: By Online delivery availability")
call_function(int(input("")))
# Out:
# Select the criteria for restaurant recommendations:
# option 1: By Name
# option 2: By City
# option 3: By Price
# option 4: By Rating
# option 5: By Cuisines
# option 6: By Online delivery availability
# 5
# Enter cuisines you prefer: Seafood
# Total number of restaurants with cuisine Seafood: 174
# Displaying a sample of 10 restaurants:
#
# Restaurant ID: 6300002
# Restaurant Name: Heat - Edsa Shangri-La
# City: Mandaluyong City
# Address: Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City
# Cuisines: Seafood, Asian, Filipino, Indian
# Price range: 4
# Aggregate rating: 4.4
#
#
# Restaurant ID: 6301290
# Restaurant Name: Vikings
# City: Pasay City
# Address: Building B, By The Bay, Seaside Boulevard, Mall of Asia Complex (MOA), Pasay City
# Cuisines: Seafood, Filipino, Asian, European
# Price range: 4
# Aggregate rating: 4.2
#
#
# Restaurant ID: 6315438
# Restaurant Name: NIU by Vikings
# City: Taguig City
# ...
